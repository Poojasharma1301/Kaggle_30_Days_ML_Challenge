# %%
try:
    from IPython import get_ipython
    get_ipython().magic('clear')
    get_ipython().magic('reset -f')
except:
    pass

# %%
X_train.head()
# Out:
#        cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont4  \
# id                                                        ...
# 257386    A    B    A    C    B    B    A    E    E    I  ...  0.277709
# 495461    A    B    A    C    B    B    A    E    C    F  ...  0.281611
# 320       B    B    A    A    B    C    A    E    E    O  ...  0.278146
# 74032     A    A    A    A    B    C    A    E    G    F  ...  0.686815
# 263581    A    A    A    C    B    D    A    D    C    G  ...  0.257302
#
#            cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# id
# 257386  0.398071  0.487289  0.869034  0.439229  0.352714  0.228661  0.363903
# 495461  0.388998  0.176158  1.000809  0.271510  0.440423  0.311323  0.164655
# 320     0.403402  0.502907  0.324734  0.511943  0.328226  0.543738  0.332158
# 74032   0.821791  0.538206  0.631913  0.405548  0.753464  0.903191  0.911150
# 263581  0.748708  0.520747  0.828223  0.996511  0.926008  0.693743  0.782965
#
#           cont12    cont13
# id
# 257386  0.331813  0.474680
# 495461  0.279045  0.452538
# 320     0.311990  0.463616
# 74032   0.611461  0.477071
# 263581  0.819652  0.772523
#
# [5 rows x 24 columns]

# %%
train['cat0'].replace({'B':1,'A':0},inplace=True)
train.cat0.unique()

train['cat1'].replace({'B':1,'A':0},inplace=True)
train.cat1.unique()
train['cat2'].replace({'B':1,'A':0},inplace=True)
train.cat2.unique()
train['cat3'].replace({'D':3,'C':2,'B':1,'A':0},inplace=True)
train.cat3.unique()
train['cat4'].replace({'D':3,'C':2,'B':1,'A':0},inplace=True)
train.cat4.unique()
train['cat5'].replace({'D':3,'C':2,'B':1,'A':0},inplace=True)
train.cat5.unique()
train['cat6'].replace({'E':4, 'H':7, 'D':3, 'B':1, 'G':6, 'C':2, 'A':0, 'I':8},inplace=True)
train.cat6.unique()
train['cat7'].replace({'E':4, 'F':5, 'D':3, 'B':1, 'G':6, 'C':2, 'A':0, 'I':8},inplace=True)
train.cat7.unique()
train['cat8'].replace({'C':2, 'A':0,'G':6, 'E':4, 'F':5, 'D':3, 'B':1},inplace=True)
train.cat8.unique()
train['cat9'].replace({'N':13, 'O':14, 'F':5, 'K':10, 'M':12, 'I':8, 'G':6, 'H':7,'L':11, 'B':1, 'A':0, 'J':9, 'D':3, 'C':2 ,'E':4},inplace=True)
train.cat9.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0915c6c8cf22> in <module>
# ----> 1 train['cat0'].replace({'B':1,'A':0},inplace=True)
#       2 train.cat0.unique()
#       3
#       4 train['cat1'].replace({'B':1,'A':0},inplace=True)
#       5 train.cat1.unique()
#
# NameError: name 'train' is not defined
